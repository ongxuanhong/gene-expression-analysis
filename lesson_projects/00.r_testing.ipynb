# %%
%load_ext rpy2.ipython

# %%
# This is a code cell - you can run R code here
x <- c(1, 2, 3, 4, 5)
mean(x)
# Out:
# [1] 3

# %%
# Create a simple plot
plot(x, type = "l")
# Out:
# plot without title
